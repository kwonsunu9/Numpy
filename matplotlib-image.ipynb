# %% [markdown]
# ## Image Processing

# %% [markdown]
# #### matplotlib.pyplot.imread
# matplotlib.pyplot.imread(fname, format=None)

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread("./1.jpg")
img.shape
# Out:
# (183, 275, 3)

# %%
plt.axis("off")
plt.gray()
plt.imshow(img)

# %%
gray_img = plt.imread('./2.jpg')
plt.axis('off')
plt.gray()
plt.imshow(gray_img)

# %%
plt.imshow(img[:,:,1])
